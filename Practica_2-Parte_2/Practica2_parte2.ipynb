# %% [markdown]
# # Practica 2 - parte 2
#
# importamos las librerias

# %%
import nltk
import ssl
import pandas as pd

# %% [markdown]
# importamos la base de datos

# %%
pr = pd.read_csv("rev-solo.csv")
pr.tail(10)
# Out:
#        Aromas include tropical fruit broom brimstone and dried herb. The palate isn't overly expressive offering unripened apple citrus and dried sage alongside brisk acidity.  \
# 129962  Intense aromas of wild cherry baking spice til...
# 129963  Blackberry cassis grilled herb and toasted aro...
# 129964  A bouquet of black cherry tart cranberry and c...
# 129965  Initially quite muted this wine slowly develop...
# 129966  While it's rich this beautiful dry wine also o...
# 129967  Notes of honeysuckle and cantaloupe sweeten th...
# 129968  Citation is given as much as a decade of bottl...
# 129969  Well-drained gravel soil gives this wine its c...
# 129970  A dry style of Pinot Gris this is crisp with s...
# 129971  Big rich and off-dry this is powered by intens...
#
#           Italy         White Blend
# 129962    Italy            Frappato
# 129963    Italy        Nero d'Avola
# 129964   Israel  Cabernet Sauvignon
# 129965   France      Gewürztraminer
# 129966   France          Pinot Gris
# 129967  Germany            Riesling
# 129968       US          Pinot Noir
# 129969   France      Gewürztraminer
# 129970   France          Pinot Gris
# 129971   France      Gewürztraminer

# %% [markdown]
# ### Se visualiza la base de datos con 10 filas, contiene la información separado por columnas. Es una base de datos creada a partir de una base de datos con más información, que es la que se muestra a continuación.

# %%
import nltk
import ssl
if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
from nltk.corpus import stopwords
print(stopwords.words("english")[:10])
from nltk.sentiment.vader import SentimentIntensityAnalyzer
s = SentimentIntensityAnalyzer() # en inglés hasta podemos distinguir entre palabras positivas y negativas
print(s.polarity_scores('useless'))
print(s.polarity_scores('marvelous'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ZAYPE\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ZAYPE\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ZAYPE\AppData\Roaming\nltk_data...
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4215}
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5994}

# %%
import pandas as pd
d = pd.read_csv("https://raw.githubusercontent.com/mayraberrones94/Ciencia_de_Datos/master/wine-reviews/wine-rev.csv")
d.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# ### importamos la base de datos completa en información

# %%
header = ['country', 'description', 'variety']
d.to_csv('solo-rev.csv', columns = header)
e = pd.read_csv('solo-rev.csv')
e.head(4)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
#
#           variety
# 0     White Blend
# 1  Portuguese Red
# 2      Pinot Gris
# 3        Riesling

# %% [markdown]
# ### En esta parte de creamos una clase para obtener la información que necesitamos de la base de datos padre

# %%
e.drop(e.columns[[0]], axis=1, inplace=True)
e.head(2)
# Out:
#     country                                        description         variety
# 0     Italy  Aromas include tropical fruit, broom, brimston...     White Blend
# 1  Portugal  This is ripe and fruity, a wine that is smooth...  Portuguese Red

# %% [markdown]
# ### Permite eliminar elementos en fila de la BD

# %%
import pandas as pd
pr = pd.read_csv('rev-solo.csv', header = None)
pr.head(3)
# Out:
#                                                    0         1               2
# 0  Aromas include tropical fruit broom brimstone ...     Italy     White Blend
# 1  This is ripe and fruity a wine that is smooth ...  Portugal  Portuguese Red
# 2  Tart and snappy the flavors of lime flesh and ...        US      Pinot Gris

# %%
pr.columns = ['description', 'country', 'variety']
n = len(pr)
spa = stopwords.words("english")
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+') # para eliminar puntuación
reemplazos = []
for r in range(n):
    original = pr.description[r]
    reemplazo = ''
    if original != 'NaN':
        quedar = [stemmer.stem(p) for p in tokenizer.tokenize(original) if p.lower() not in spa]
        reemplazo = ' '.join(quedar)
    reemplazos.append(reemplazo)
pr['limpios'] = reemplazos
texto = ' '.join(reemplazos)
nube = WordCloud().generate(texto)
plt.rcParams["figure.figsize"] = [15, 7]
plt.imshow(nube)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Esta imagen nos permite visualizar las palabras más repetidas en nuestra bd

# %%
header = ['description','country',  'variety']
writer = e[e['country'] == 'US']
writer.to_csv('us-wine.csv', columns = header, index=False)

lol = pd.read_csv('us-wine.csv')
lol.head(4)
# Out:
#                                          description country  \
# 0  Tart and snappy, the flavors of lime flesh and...      US
# 1  Pineapple rind, lemon pith and orange blossom ...      US
# 2  Much like the regular bottling from 2012, this...      US
# 3  Soft, supple plum envelopes an oaky structure ...      US
#
#               variety
# 0          Pinot Gris
# 1            Riesling
# 2          Pinot Noir
# 3  Cabernet Sauvignon

# %%
header = ['description','country',  'variety']
writer = e[e['country'] == 'Italy']
writer.to_csv('italy-wine.csv', columns = header, index=False)

lol = pd.read_csv('italy-wine.csv')
lol.head(4)
# Out:
#                                          description country  \
# 0  Aromas include tropical fruit, broom, brimston...   Italy
# 1  Here's a bright, informal red that opens with ...   Italy
# 2  This is dominated by oak and oak-driven aromas...   Italy
# 3  Delicate aromas recall white flower and citrus...   Italy
#
#              variety
# 0        White Blend
# 1           Frappato
# 2  Nerello Mascalese
# 3        White Blend

# %%
header = ['description','country',  'variety']
writer = e[e['country'] == 'Portugal']
writer.to_csv('portugal-wine.csv', columns = header, index=False)

lol = pd.read_csv('portugal-wine.csv')
lol.head(4)
# Out:
#                                          description   country  \
# 0  This is ripe and fruity, a wine that is smooth...  Portugal
# 1  Grown on the sandy soil of Tejo, the wine is t...  Portugal
# 2  This bottling shows a rich, wood-aged wine, fu...  Portugal
# 3  From an estate in the south of the Alentejo, t...  Portugal
#
#             variety
# 0    Portuguese Red
# 1  Touriga Nacional
# 2  Portuguese White
# 3    Portuguese Red

# %% [markdown]
# ## Ahora separamos los datos en 3 archivos csv, cada uno correspondiendo a un país de la columna "country" de nuestra bd. Que en este caso son los siguientes: "Italy", "Israel" y "France".

# %%
import ssl
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import RegexpTokenizer

if getattr(ssl, '_create_unverified_context', None):
    ssl._create_default_https_context = ssl._create_unverified_context
dini = pd.read_csv("portugal-wine.csv", header = None)
dmcu = pd.read_csv("us-wine.csv", header = None)
dord = pd.read_csv("italy-wine.csv", header = None)
cols = ['description', 'country', 'variety']
dini.columns = cols
dmcu.columns = cols
dord.columns = cols
spa = stopwords.words("english")
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'\w+') # para eliminar puntuación
plt.rcParams["figure.figsize"] = [18, 9]
f = plt.figure() 
lbls = ["Portugal", "US", "Italia"]
i = 1
for d in [dini, dmcu, dord]:
    lbl = lbls.pop(0)
    reemplazos = []
    for r in range(len(d)):
        original = d.description[r]
        reemplazo = ''
        if original != 'NaN':
            quedar = [stemmer.stem(p) for p in tokenizer.tokenize(original) if p.lower() not in spa]
            reemplazo = ' '.join(quedar)
        reemplazos.append(reemplazo)
    d['limpios'] = reemplazos
    for tipo in lbls:
        sf = plt.subplot(3, 3, i)
        i += 1
        texto = ' '.join(reemplazos)
        sf.set_title(tipo)
        nube = WordCloud().generate(texto)
        sf.imshow(nube)
        sf.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Como se puede observar cada país es distinto del otro, cada país muestrala información que tiene dentro de, por lo tanto en una investigación o proyecto nos puede servir para hacer comparaciones o sacar los datos más relevantes de cada uno.
